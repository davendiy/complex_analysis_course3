# %%
import wayplt
import numpy as np


def test_func(t):
    return complex(np.cos(t) * 3, np.sin(t) * 2)

wayplt.plot_complex_curve(test_func, 0, 2*np.pi)

# %%
import matplotlib.pyplot as plt

xx, yy = np.meshgrid(np.arange(0, 1, 0.1), np.arange(0, 1, 0.2))
plt.scatter(xx, yy)
